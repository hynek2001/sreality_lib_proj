# %%
from srealitylib.coldb import querySreality
import logging
sfilter={
    "category_main_cb": 1,
    "category_sub_cb":"11|12",
    "category_type_cb": 1,
    "locality_region_id": 10,
}
logging.getLogger().setLevel(logging.ERROR)
res = querySreality(sfilter=sfilter)
for item in res:
    print("{0:45s} {1:35s} {2:10s}".format(str(item['name']),str(item['locality']),str(item['price'])  ))
#locality hash_id price  name
# Out:
# Prodej bytu 4+kk 108 m²                       U Sluncové, Praha 8 - Karlín        12172367
# Prodej bytu 5+1 161 m²                        Valentinská, Praha 1 - Staré Město  28500000
# Prodej bytu 6 pokojů a více 558 m² (Mezonet)  Nad obcí II, Praha 4 - Krč          1
# Prodej bytu 6 pokojů a více 215 m² (Mezonet)  Mlynářská, Praha 1 - Nové Město     1
# Prodej bytu 5+1 220 m²                        Gorazdova, Praha 2 - Nové Město     24000000
# Prodej bytu 6 pokojů a více 275 m²            Pod Žvahovem, Praha 5 - Hlubočepy   26500000
# Prodej bytu 6 pokojů a více 247 m² (Mezonet)  Erbenova, Praha 5                   44990000
# Prodej bytu 6 pokojů a více 210 m²            Branická, Praha - Praha 4           19922838
# Prodej bytu 5+1 121 m²                        Balbínova, Praha 2 - Vinohrady      12699000
# Prodej bytu 5+1 145 m²                        Legerova, Praha 2 - Vinohrady       15590000
# ...
